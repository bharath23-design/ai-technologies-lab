# %% [markdown]
# 1 Agents - shallow Agents
# 2 Deep Agent
#
# Basic Agent [shallow agent]= Input -> LLM [brain]- connected with Tools [ serper api,duck duck go]-> O/p
# cons - No expltict planning,complex queries can't be handle,limited context retention
#
# Langraph Multi AI agenet - for complex agetn and we can connect to the multi AI agnet and do the job, we can add Human in the loop and memory context
#
# Deep Agents = example; Deep search agent in claude,chatgpt,manus ai,
# Architecure is different, 4 properites ,1 is Planning Tool,2nd is Sub agents,3rd system prompt and 4th is Files System
# planning -> Some kind of planning will happen [ todo list]
# sub agents -> each todo list be converted into sub agents
# System Prompt ->
# File system -> persistent memory,which will be able to accessble to all the sub agents [ share memory,etc]
#
#
# Then generate the output
